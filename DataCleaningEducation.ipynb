# %% [markdown]
# ## Data Cleaning Assignment
#
# For this assignment we'll focus on cleaning the TOTAL_REVENUE and TOTAL_EXPENDITURE columns in relation to year and state in our dataset found here: [U.S. Education Dataset](https://www.kaggle.com/noriuk/us-education-datasets-unification-project/home)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
education_df = pd.read_csv('C:\Thinkful\Data Cleaning\states_all.csv')

# %% [markdown]
# Let's see the data types and how many null values we're working with.

# %%
##show data types for each column
education_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1492 entries, 0 to 1491
# Data columns (total 25 columns):
# PRIMARY_KEY                     1492 non-null object
# STATE                           1492 non-null object
# YEAR                            1492 non-null int64
# ENROLL                          1229 non-null float64
# TOTAL_REVENUE                   1280 non-null float64
# FEDERAL_REVENUE                 1280 non-null float64
# STATE_REVENUE                   1280 non-null float64
# LOCAL_REVENUE                   1280 non-null float64
# TOTAL_EXPENDITURE               1280 non-null float64
# INSTRUCTION_EXPENDITURE         1280 non-null float64
# SUPPORT_SERVICES_EXPENDITURE    1280 non-null float64
# OTHER_EXPENDITURE               1229 non-null float64
# CAPITAL_OUTLAY_EXPENDITURE      1280 non-null float64
# GRADES_PK_G                     1319 non-null float64
# GRADES_KG_G                     1360 non-null float64
# GRADES_4_G                      1361 non-null float64
# GRADES_8_G                      1361 non-null float64
# GRADES_12_G                     1361 non-null float64
# GRADES_1_8_G                    1361 non-null float64
# GRADES_9_12_G                   1361 non-null float64
# GRADES_ALL_G                    1319 non-null float64
# AVG_MATH_4_SCORE                536 non-null float64
# AVG_MATH_8_SCORE                532 non-null float64
# AVG_READING_4_SCORE             533 non-null float64
# AVG_READING_8_SCORE             498 non-null float64
# dtypes: float64(22), int64(1), object(2)
# memory usage: 279.8+ KB

# %%
##show percentage of null values in each column
education_df.isnull().mean()
# Out:
# PRIMARY_KEY                     0.000000
# STATE                           0.000000
# YEAR                            0.000000
# ENROLL                          0.176273
# TOTAL_REVENUE                   0.142091
# FEDERAL_REVENUE                 0.142091
# STATE_REVENUE                   0.142091
# LOCAL_REVENUE                   0.142091
# TOTAL_EXPENDITURE               0.142091
# INSTRUCTION_EXPENDITURE         0.142091
# SUPPORT_SERVICES_EXPENDITURE    0.142091
# OTHER_EXPENDITURE               0.176273
# CAPITAL_OUTLAY_EXPENDITURE      0.142091
# GRADES_PK_G                     0.115952
# GRADES_KG_G                     0.088472
# GRADES_4_G                      0.087802
# GRADES_8_G                      0.087802
# GRADES_12_G                     0.087802
# GRADES_1_8_G                    0.087802
# GRADES_9_12_G                   0.087802
# GRADES_ALL_G                    0.115952
# AVG_MATH_4_SCORE                0.640751
# AVG_MATH_8_SCORE                0.643432
# AVG_READING_4_SCORE             0.642761
# AVG_READING_8_SCORE             0.666220
# dtype: float64

# %% [markdown]
# ### Dealing with missing values

# %%
##create new df with only our columns of focus
rev_exp = education_df[['STATE','YEAR','TOTAL_REVENUE','TOTAL_EXPENDITURE']]
rev_exp.loc[rev_exp['YEAR'] == 2017]
# Out:
#                      STATE  YEAR  TOTAL_REVENUE  TOTAL_EXPENDITURE
# 1441               ALABAMA  2017            NaN                NaN
# 1442                ALASKA  2017            NaN                NaN
# 1443               ARIZONA  2017            NaN                NaN
# 1444              ARKANSAS  2017            NaN                NaN
# 1445            CALIFORNIA  2017            NaN                NaN
# 1446              COLORADO  2017            NaN                NaN
# 1447           CONNECTICUT  2017            NaN                NaN
# 1448              DELAWARE  2017            NaN                NaN
# 1449  DISTRICT_OF_COLUMBIA  2017            NaN                NaN
# 1450               FLORIDA  2017            NaN                NaN
# 1451               GEORGIA  2017            NaN                NaN
# 1452                HAWAII  2017            NaN                NaN
# 1453                 IDAHO  2017            NaN                NaN
# 1454              ILLINOIS  2017            NaN                NaN
# 1455               INDIANA  2017            NaN                NaN
# 1456                  IOWA  2017            NaN                NaN
# 1457                KANSAS  2017            NaN                NaN
# 1458              KENTUCKY  2017            NaN                NaN
# 1459             LOUISIANA  2017            NaN                NaN
# 1460                 MAINE  2017            NaN                NaN
# 1461              MARYLAND  2017            NaN                NaN
# 1462         MASSACHUSETTS  2017            NaN                NaN
# 1463              MICHIGAN  2017            NaN                NaN
# 1464             MINNESOTA  2017            NaN                NaN
# 1465           MISSISSIPPI  2017            NaN                NaN
# 1466              MISSOURI  2017            NaN                NaN
# 1467               MONTANA  2017            NaN                NaN
# 1468              NEBRASKA  2017            NaN                NaN
# 1469                NEVADA  2017            NaN                NaN
# 1470         NEW_HAMPSHIRE  2017            NaN                NaN
# 1471            NEW_JERSEY  2017            NaN                NaN
# 1472            NEW_MEXICO  2017            NaN                NaN
# 1473              NEW_YORK  2017            NaN                NaN
# 1474        NORTH_CAROLINA  2017            NaN                NaN
# 1475          NORTH_DAKOTA  2017            NaN                NaN
# 1476                  OHIO  2017            NaN                NaN
# 1477              OKLAHOMA  2017            NaN                NaN
# 1478                OREGON  2017            NaN                NaN
# 1479          PENNSYLVANIA  2017            NaN                NaN
# 1480          RHODE_ISLAND  2017            NaN                NaN
# 1481        SOUTH_CAROLINA  2017            NaN                NaN
# 1482          SOUTH_DAKOTA  2017            NaN                NaN
# 1483             TENNESSEE  2017            NaN                NaN
# 1484                 TEXAS  2017            NaN                NaN
# 1485                  UTAH  2017            NaN                NaN
# 1486               VERMONT  2017            NaN                NaN
# 1487              VIRGINIA  2017            NaN                NaN
# 1488            WASHINGTON  2017            NaN                NaN
# 1489         WEST_VIRGINIA  2017            NaN                NaN
# 1490             WISCONSIN  2017            NaN                NaN
# 1491               WYOMING  2017            NaN                NaN

# %% [markdown]
# We'll delete 2017 since no state has data for it.

# %%
## delete 2017 rows
rev_exp = rev_exp.loc[rev_exp['YEAR'] != 2017]

# %% [markdown]
# Now lets check each year to find more null values.

# %%
## count null values for 2016
rev_exp.loc[rev_exp['YEAR'] == 2016].isnull().sum()
# Out:
# STATE                0
# YEAR                 0
# TOTAL_REVENUE        0
# TOTAL_EXPENDITURE    0
# dtype: int64

# %%
## count null values for 2015
rev_exp.loc[rev_exp['YEAR'] == 2015].isnull().sum()
# Out:
# STATE                0
# YEAR                 0
# TOTAL_REVENUE        6
# TOTAL_EXPENDITURE    6
# dtype: int64

# %%
rev_exp.loc[rev_exp['YEAR'] == 2015]
# Out:
#                                          STATE  YEAR  TOTAL_REVENUE  \
# 1178                                   ALABAMA  2015      7360222.0
# 1179                                    ALASKA  2015      2920986.0
# 1180                                   ARIZONA  2015      8230507.0
# 1181                                  ARKANSAS  2015      5308625.0
# 1182                                CALIFORNIA  2015     78248042.0
# 1183                                  COLORADO  2015      9648297.0
# 1184                               CONNECTICUT  2015     11099837.0
# 1185                                  DELAWARE  2015      2017075.0
# 1186                      DISTRICT_OF_COLUMBIA  2015      1382282.0
# 1187                                   FLORIDA  2015     26971491.0
# 1188                                   GEORGIA  2015     18584666.0
# 1189                                    HAWAII  2015      2703683.0
# 1190                                     IDAHO  2015      2167967.0
# 1191                                  ILLINOIS  2015     32096832.0
# 1192                                   INDIANA  2015     12456571.0
# 1193                                      IOWA  2015      6714410.0
# 1194                                    KANSAS  2015      5991731.0
# 1195                                  KENTUCKY  2015      7548871.0
# 1196                                 LOUISIANA  2015      8448743.0
# 1197                                     MAINE  2015      2739589.0
# 1198                                  MARYLAND  2015     14491642.0
# 1199                             MASSACHUSETTS  2015     16985185.0
# 1200                                  MICHIGAN  2015     19025996.0
# 1201                                 MINNESOTA  2015     11684249.0
# 1202                               MISSISSIPPI  2015      4592343.0
# 1203                                  MISSOURI  2015     10623391.0
# 1204                                   MONTANA  2015      1804339.0
# 1205                                  NEBRASKA  2015      4248695.0
# 1206                                    NEVADA  2015      4345419.0
# 1207                             NEW_HAMPSHIRE  2015      3093061.0
# 1208                                NEW_JERSEY  2015     29335237.0
# 1209                                NEW_MEXICO  2015      3789651.0
# 1210                                  NEW_YORK  2015     63712218.0
# 1211                            NORTH_CAROLINA  2015     13146934.0
# 1212                              NORTH_DAKOTA  2015      1644533.0
# 1213                                      OHIO  2015     24378660.0
# 1214                                  OKLAHOMA  2015      6121188.0
# 1215                                    OREGON  2015      7111710.0
# 1216                              PENNSYLVANIA  2015     29967185.0
# 1217                              RHODE_ISLAND  2015      2367068.0
# 1218                            SOUTH_CAROLINA  2015      8759944.0
# 1219                              SOUTH_DAKOTA  2015      1415149.0
# 1220                                 TENNESSEE  2015      9455920.0
# 1221                                     TEXAS  2015     55582029.0
# 1222                                      UTAH  2015      4705084.0
# 1223                                   VERMONT  2015      1996795.0
# 1224                                  VIRGINIA  2015     15857524.0
# 1225                                WASHINGTON  2015     13709442.0
# 1226                             WEST_VIRGINIA  2015      3478401.0
# 1227                                 WISCONSIN  2015     11637376.0
# 1228                                   WYOMING  2015      1962874.0
# 1300                            AMERICAN_SAMOA  2015            NaN
# 1301                BUREAU_OF_INDIAN_EDUCATION  2015            NaN
# 1302  DEPARTMENT_OF_DEFENSE_EDUCATION_ACTIVITY  2015            NaN
# 1303                                      GUAM  2015            NaN
# 1304                               PUERTO_RICO  2015            NaN
# 1305                       U.S._VIRGIN_ISLANDS  2015            NaN
#
#       TOTAL_EXPENDITURE
# 1178          7501799.0
# 1179          2968341.0
# 1180          7902600.0
# 1181          5350543.0
# 1182         78365958.0
# 1183          9557682.0
# 1184         10542667.0
# 1185          1975093.0
# 1186          1360942.0
# 1187         27277049.0
# 1188         18501103.0
# 1189          2521004.0
# 1190          2029520.0
# 1191         32410033.0
# 1192         11378564.0
# 1193          6772654.0
# 1194          6175724.0
# 1195          7554887.0
# 1196          8437263.0
# 1197          2596180.0
# 1198         13882823.0
# 1199         16972319.0
# 1200         17742903.0
# 1201         11969872.0
# 1202          4624539.0
# 1203         10540353.0
# 1204          1804841.0
# 1205          4283846.0
# 1206          4183085.0
# 1207          3044720.0
# 1208         28809725.0
# 1209          3846641.0
# 1210         65094591.0
# 1211         14060699.0
# 1212          1804762.0
# 1213         22561728.0
# 1214          6184819.0
# 1215          7011609.0
# 1216         29690645.0
# 1217          2326473.0
# 1218          8783362.0
# 1219          1464781.0
# 1220          9562527.0
# 1221         56255791.0
# 1222          4537962.0
# 1223          1969415.0
# 1224         16113212.0
# 1225         13630138.0
# 1226          3466981.0
# 1227         11553677.0
# 1228          1942406.0
# 1300                NaN
# 1301                NaN
# 1302                NaN
# 1303                NaN
# 1304                NaN
# 1305                NaN

# %%
## count null values for 2014
rev_exp.loc[rev_exp['YEAR'] == 2014].isnull().sum()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-0ac491683691> in <module>
#       1 ## count null values for 2014
# ----> 2 rev_exp.loc[rev_exp['YEAR'] == 2014].isnull().sum()
#
# NameError: name 'rev_exp' is not defined

# %%
rev_exp.loc[rev_exp['YEAR'] == 2014]
# Out:
#                          STATE  YEAR  TOTAL_REVENUE  TOTAL_EXPENDITURE
# 1127                   ALABAMA  2014      7357267.0          7587737.0
# 1128                    ALASKA  2014      2663647.0          2727056.0
# 1129                   ARIZONA  2014      8361708.0          8109460.0
# 1130                  ARKANSAS  2014      5193218.0          5242672.0
# 1131                CALIFORNIA  2014     72389126.0         72506810.0
# 1132                  COLORADO  2014      9162406.0          9286626.0
# 1133               CONNECTICUT  2014     10743919.0         10201500.0
# 1134                  DELAWARE  2014      1954374.0          1988535.0
# 1135      DISTRICT_OF_COLUMBIA  2014      1342220.0          1313289.0
# 1136                   FLORIDA  2014     26077462.0         26523658.0
# 1137                   GEORGIA  2014     17821620.0         17668352.0
# 1138                    HAWAII  2014      2696766.0          2504144.0
# 1139                     IDAHO  2014      2084970.0          2012852.0
# 1140                  ILLINOIS  2014     31085621.0         31080869.0
# 1141                   INDIANA  2014     12399402.0         11136045.0
# 1142                      IOWA  2014      6455928.0          6541553.0
# 1143                    KANSAS  2014      5813985.0          5957954.0
# 1144                  KENTUCKY  2014      7229857.0          7346219.0
# 1145                 LOUISIANA  2014      8352703.0          8140649.0
# 1146                     MAINE  2014      2675648.0          2550302.0
# 1147                  MARYLAND  2014     13982544.0         13712839.0
# 1148             MASSACHUSETTS  2014     16609204.0         16518383.0
# 1149                  MICHIGAN  2014     18457253.0         17358365.0
# 1150                 MINNESOTA  2014     11168633.0         11300786.0
# 1151               MISSISSIPPI  2014      4480105.0          4463078.0
# 1152                  MISSOURI  2014     10256615.0         10324249.0
# 1153                   MONTANA  2014      1729712.0          1754324.0
# 1154                  NEBRASKA  2014      4005091.0          4008633.0
# 1155                    NEVADA  2014      4203255.0          4043820.0
# 1156             NEW_HAMPSHIRE  2014      3042994.0          2960615.0
# 1157                NEW_JERSEY  2014     28454548.0         27742203.0
# 1158                NEW_MEXICO  2014      3601387.0          3576216.0
# 1159                  NEW_YORK  2014     61337112.0         62556193.0
# 1160            NORTH_CAROLINA  2014     13462754.0         13540706.0
# 1161              NORTH_DAKOTA  2014      1568997.0          1597210.0
# 1162                      OHIO  2014     23297509.0         21847582.0
# 1163                  OKLAHOMA  2014      6034336.0          6026661.0
# 1164                    OREGON  2014      6621363.0          6453635.0
# 1165              PENNSYLVANIA  2014     29068069.0         28620630.0
# 1166              RHODE_ISLAND  2014      2313010.0          2258076.0
# 1167            SOUTH_CAROLINA  2014      8417698.0          8452743.0
# 1168              SOUTH_DAKOTA  2014      1345549.0          1355439.0
# 1169                 TENNESSEE  2014      9237782.0          9432883.0
# 1170                     TEXAS  2014     52776853.0         53096761.0
# 1171                      UTAH  2014      4405929.0          4385896.0
# 1172                   VERMONT  2014      1895044.0          1876197.0
# 1173                  VIRGINIA  2014     15347862.0         15690444.0
# 1174                WASHINGTON  2014     13040197.0         12806300.0
# 1175             WEST_VIRGINIA  2014      3514889.0          3499873.0
# 1176                 WISCONSIN  2014     11330253.0         11255186.0
# 1177                   WYOMING  2014      1772633.0          1775999.0
# 1295  BUREAU_OF_INDIAN_AFFAIRS  2014            NaN                NaN
# 1296     DEPARTMENT_OF_DEFENSE  2014            NaN                NaN
# 1297                      GUAM  2014            NaN                NaN
# 1298               PUERTO_RICO  2014            NaN                NaN
# 1299            VIRGIN_ISLANDS  2014            NaN                NaN

# %%
print(rev_exp['STATE'].unique())
# Out:
# ['ALABAMA' 'ALASKA' 'ARIZONA' 'ARKANSAS' 'CALIFORNIA' 'COLORADO'
#  'CONNECTICUT' 'DELAWARE' 'DISTRICT_OF_COLUMBIA' 'FLORIDA' 'GEORGIA'
#  'HAWAII' 'IDAHO' 'ILLINOIS' 'INDIANA' 'IOWA' 'KANSAS' 'KENTUCKY'
#  'LOUISIANA' 'MAINE' 'MARYLAND' 'MASSACHUSETTS' 'MICHIGAN' 'MINNESOTA'
#  'MISSISSIPPI' 'MISSOURI' 'MONTANA' 'NEBRASKA' 'NEVADA' 'NEW_HAMPSHIRE'
#  'NEW_JERSEY' 'NEW_MEXICO' 'NEW_YORK' 'NORTH_CAROLINA' 'NORTH_DAKOTA'
#  'OHIO' 'OKLAHOMA' 'OREGON' 'PENNSYLVANIA' 'RHODE_ISLAND' 'SOUTH_CAROLINA'
#  'SOUTH_DAKOTA' 'TENNESSEE' 'TEXAS' 'UTAH' 'VERMONT' 'VIRGINIA'
#  'WASHINGTON' 'WEST_VIRGINIA' 'WISCONSIN' 'WYOMING' 'AMERICAN_SAMOA'
#  'BUREAU_OF_INDIAN_AFFAIRS' 'DOD_DOMESTIC' 'DOD_OVERSEAS' 'GUAM'
#  'NORTHERN_MARIANAS' 'PUERTO_RICO' 'VIRGIN_ISLANDS' 'BI' 'DD'
#  'NORTHERN_MARIANA_ISLANDS' 'DEPARTMENT_OF_DEFENSE'
#  'BUREAU_OF_INDIAN_EDUCATION' 'DEPARTMENT_OF_DEFENSE_EDUCATION_ACTIVITY'
#  'U.S._VIRGIN_ISLANDS' 'DOD_(OVERSEAS_AND_DOMESTIC_COMBINED)' 'BIE'
#  'COMMONWEALTH_OF_MARIANAS' 'DOD_-_FOREIGN' 'AS' 'GU' 'MP' 'PR' 'VI'
#  'MARIANAS' 'BUREAU_OF_INDIAN_EDUCATIO' 'DOD_-_DOMESTIC' 'DOD_-_OVERSEAS'
#  'DOD']

# %% [markdown]
# I'm going to narrow it down to just the 50 states since the territories have much less reliable information recorded in the dataset.

# %%
##deleting all non 50 state rows.
##I'm sure theres a more concise way to do this!
rev_exp = rev_exp.loc[rev_exp['STATE'] != 'DISTRICT_OF_COLUMBIA']
rev_exp = rev_exp.loc[rev_exp['STATE'] != 'BUREAU_OF_INDIAN_AFFAIRS']
rev_exp = rev_exp.loc[rev_exp['STATE'] != 'DOD_DOMESTIC']
rev_exp = rev_exp.loc[rev_exp['STATE'] != 'DOD_OVERSEAS']
rev_exp = rev_exp.loc[rev_exp['STATE'] != 'GUAM']
rev_exp = rev_exp.loc[rev_exp['STATE'] != 'NORTHERN_MARIANAS']
rev_exp = rev_exp.loc[rev_exp['STATE'] != 'PUERTO_RICO']
rev_exp = rev_exp.loc[rev_exp['STATE'] != 'VIRGIN_ISLANDS']
rev_exp = rev_exp.loc[rev_exp['STATE'] != 'BI']
rev_exp = rev_exp.loc[rev_exp['STATE'] != 'DD']
rev_exp = rev_exp.loc[rev_exp['STATE'] != 'NORTHERN_MARIANA_ISLANDS']
rev_exp = rev_exp.loc[rev_exp['STATE'] != 'DEPARTMENT_OF_DEFENSE']
rev_exp = rev_exp.loc[rev_exp['STATE'] != 'DEPARTMENT_OF_DEFENSE_EDUCATION_ACTIVITY']
rev_exp = rev_exp.loc[rev_exp['STATE'] != 'U.S._VIRGIN_ISLANDS']
rev_exp = rev_exp.loc[rev_exp['STATE'] != 'DOD_(OVERSEAS_AND_DOMESTIC_COMBINED)']
rev_exp = rev_exp.loc[rev_exp['STATE'] != 'BIE']
rev_exp = rev_exp.loc[rev_exp['STATE'] != 'COMMONWEALTH_OF_MARIANAS']
rev_exp = rev_exp.loc[rev_exp['STATE'] != 'DOD_-_FOREIGN']
rev_exp = rev_exp.loc[rev_exp['STATE'] != 'AS']
rev_exp = rev_exp.loc[rev_exp['STATE'] != 'GU']
rev_exp = rev_exp.loc[rev_exp['STATE'] != 'PR']
rev_exp = rev_exp.loc[rev_exp['STATE'] != 'VI']
rev_exp = rev_exp.loc[rev_exp['STATE'] != 'MARIANAS']
rev_exp = rev_exp.loc[rev_exp['STATE'] != 'BUREAU_OF_INDIAN_EDUCATIO']
rev_exp = rev_exp.loc[rev_exp['STATE'] != 'DOD_-_DOMESTIC']
rev_exp = rev_exp.loc[rev_exp['STATE'] != 'DOD_-_OVERSEAS']
rev_exp = rev_exp.loc[rev_exp['STATE'] != 'DOD']
rev_exp = rev_exp.loc[rev_exp['STATE'] != 'AMERICAN_SAMOA']
rev_exp = rev_exp.loc[rev_exp['STATE'] != 'BUREAU_OF_INDIAN_EDUCATION']
rev_exp = rev_exp.loc[rev_exp['STATE'] != 'MP']

state_list = [a,b,c..]
Ravi Kora10:25 AM
rev_exp.loc['STATE'].isin('a', b')
Ravi Kora10:26 AM
rev_exp.loc[~ rev_exp['STATE'].isin('a', 'b')]
Ravi Kora10:28 AM
for s in state_lst:
rev_exp = rev_exp.loc[rev_exp['STATE'] != s]

# %% [markdown]
# Let's see how that does.

# %%
rev_exp.isnull().sum()
# Out:
# STATE                0
# YEAR                 0
# TOTAL_REVENUE        0
# TOTAL_EXPENDITURE    0
# dtype: int64

# %% [markdown]
# Perfect! It seems as though the territorries and other erroneuos non-state entities didn't gather these financial data. Now that our missing values are gone, it's time to check for outliers.
#
# ### Checking for outliers

# %%
##revenue boxplot
sns.boxplot(rev_exp['TOTAL_REVENUE'])
plt.title('Total Revenue Box Plot')
# Out:
# Text(0.5, 1.0, 'Total Revenue Box Plot')

# %% [markdown]
# This shows many potential outliers, but obviously it's only because of the difference between states like Texas and California versus tiny states like Rhode Island and Delaware. Let's keep exploring.

# %%
##distribution plot of revenue
sns.distplot(rev_exp['TOTAL_REVENUE'])
plt.title('Total Revenue Distribution Plot')
# Out:
# Text(0.5, 1.0, 'Total Revenue Distribution Plot')

# %%
##lowest 5 total revenue
rev_exp.sort_values(by=['TOTAL_REVENUE']).head()
# Out:
#             STATE  YEAR  TOTAL_REVENUE  TOTAL_EXPENDITURE
# 92   SOUTH_DAKOTA  1993       465650.0           481665.0
# 143  SOUTH_DAKOTA  1994       507927.0           525289.0
# 41   SOUTH_DAKOTA  1992       551668.0           593126.0
# 34   NORTH_DAKOTA  1992       559481.0           553732.0
# 85   NORTH_DAKOTA  1993       580148.0           588983.0

# %%
##highest 5 total revenue
rev_exp.sort_values(by=['TOTAL_REVENUE']).tail()
# Out:
#            STATE  YEAR  TOTAL_REVENUE  TOTAL_EXPENDITURE
# 769   CALIFORNIA  2007     72516936.0         73225422.0
# 874   CALIFORNIA  2009     73958896.0         74766086.0
# 820   CALIFORNIA  2008     74626928.0         76618865.0
# 1182  CALIFORNIA  2015     78248042.0         78365958.0
# 1233  CALIFORNIA  2016     89217262.0         85320133.0

# %% [markdown]
# Even further evidence that these data seem correct: South Dakota revenue in 1993 versus California revenue in 2016 is obviously going to be an enourmous difference. The next step should be to create a column that is the difference between revenue and expenditure to normalize the data.

# %%
##create new deficit column
rev_exp['DEFICIT'] = rev_exp['TOTAL_REVENUE'] - rev_exp['TOTAL_EXPENDITURE']
rev_exp.head()
# Out:
#         STATE  YEAR  TOTAL_REVENUE  TOTAL_EXPENDITURE   DEFICIT
# 0     ALABAMA  1992      2678885.0          2653798.0   25087.0
# 1      ALASKA  1992      1049591.0           972488.0   77103.0
# 2     ARIZONA  1992      3258079.0          3401580.0 -143501.0
# 3    ARKANSAS  1992      1711959.0          1743022.0  -31063.0
# 4  CALIFORNIA  1992     26260025.0         27138832.0 -878807.0

# %%
##organize new df sorted by deficit
deficit_df = rev_exp.sort_values(by=['DEFICIT']).reset_index().drop(columns=['index'])
deficit_df.head()
# Out:
#         STATE  YEAR  TOTAL_REVENUE  TOTAL_EXPENDITURE    DEFICIT
# 0       TEXAS  2009     48087531.0         53575273.0 -5487742.0
# 1    NEW_YORK  2010     55453300.0         60067253.0 -4613953.0
# 2  CALIFORNIA  2005     62171797.0         66196072.0 -4024275.0
# 3       TEXAS  2008     46245975.0         50205827.0 -3959852.0
# 4  CALIFORNIA  2010     67356719.0         71227111.0 -3870392.0

# %%
##deficit boxplot
sns.boxplot(deficit_df['DEFICIT'])
plt.title('Deficit Boxplot')
# Out:
# Text(0.5, 1.0, 'Deficit Boxplot')

# %%
##deficit distribution plot
sns.distplot(deficit_df['DEFICIT'])
plt.title('Deficit Distribution Plot')
# Out:
# Text(0.5, 1.0, 'Deficit Distribution Plot')

# %%
deficit_df['DEFICIT'].mean()
# Out:
# -106931.59185303515

# %% [markdown]
# While there are extreme values, it seems to be pretty normally distributed with the mean close to 0. However, we can normalize the data even more by creating a deficit per capita feature.
